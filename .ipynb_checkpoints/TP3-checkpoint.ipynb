# %%
I Question 12 : Codez une fonction v = translation_colonnes(u,t) qui translate
chaque colonne k de u par le vecteur t(k) en utilisant la TFD unidimensionnelle (Aide Matlab
: si A est une matrice, alors fft(A) renvoie la matrice des TFD des colonnes de A). Testez
cette fonction avec des vecteurs de translation non entier

# %%
from scipy import misc
#f = misc.imread('house.png', flatten=False, mode='RGB')
f =misc.imread('house.png',flatten=False, mode= 'F')

f = f/255

print(f.shape)
print(f_prime.shape)
import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()

plt.imshow(f_prime)
plt.show()
# Out:
# (512, 512)
# (512, 512)

# %%
#Q1 et Q2 à partir de 16 ça commence à devenir moche 
import numpy as np 

def requantification(image, N):
    J= np.ceil(image*N)/N
    plt.imshow(J)
    plt.show()
    return J
    
f_req = requantification(f, 4)

# %%
from numpy.fft import fft2, fft 
freq_tf2 = np.fft.fft2(f_req)
freq_tf1 = np.fft.fft(f_req)
print(freq_tf1.shape , freq_tf2.shape)
# Out:
# (512, 512) (512, 512)

# %%
I Question 12 : Codez une fonction v = translation_colonnes(u,t) qui translate
chaque colonne k de u par le vecteur t(k) en utilisant la TFD unidimensionnelle (Aide Matlab
: si A est une matrice, alors fft(A) renvoie la matrice des TFD des colonnes de A). Testez
cette fonction avec des vecteurs de translation non entier

# %%
import cmath
import math
from numpy.fft import fft2, fft ,ifft2

# %%
img= f
N=img.shape[0]
M=img.shape[1]

tau_x= 52 
tau_y= 200

[k,l] = np.meshgrid(np.linspace(0,M,M),np.linspace(0,N,N))
print(k)


Iu=img

fft2_img=fft2(Iu)

fft2_img=fft2_img*np.exp(1j*(-2*math.pi*k*tau_y/M))*np.exp(1j*(2*math.pi*l*tau_x/N))

ifft2_img=ifft2(fft2_img)

plt.imshow(ifft2_img.real, plt.cm.binary)
plt.show()
# Out:
# [[   0.            1.00195695    2.00391389 ...,  509.99608611
#    510.99804305  512.        ]
#  [   0.            1.00195695    2.00391389 ...,  509.99608611
#    510.99804305  512.        ]
#  [   0.            1.00195695    2.00391389 ...,  509.99608611
#    510.99804305  512.        ]
#  ...,
#  [   0.            1.00195695    2.00391389 ...,  509.99608611
#    510.99804305  512.        ]
#  [   0.            1.00195695    2.00391389 ...,  509.99608611
#    510.99804305  512.        ]
#  [   0.            1.00195695    2.00391389 ...,  509.99608611
#    510.99804305  512.        ]]

# %%
img = np.zeros((50, 50))
img[20:25, 20:25]=1
plt.imshow(img)
plt.show()

# %%
def c_exp( arg):
    return cmath.rect(1, arg)

def interpolation(u_tf, to1, to2, x, y):
    somme = 0 
    dim1, dim2 = u_tf.shape 
    zero=[0]
    for k in range(0,int(dim1/2)+1):
        for l in range(0, int(dim2/2)+1):
            somme = somme + u_tf[k, l]* c_exp(-2*math.pi*((k/(dim1))*to1+(l/(dim2))*to2))* c_exp(2*math.pi*((k*x*1/(dim1))+(l*y*1/(dim2))))

    for k in list(range(int(dim1/2)+1, dim1))   :
        for l in list(range(int(dim2/2)+1, dim2))   :
            somme = somme + u_tf[k, l]* c_exp(-2*math.pi*(((k-dim1)/(dim1))*to1+((l-dim2)/(dim2))*to2))* c_exp(2*math.pi*(((k-dim1)*x*1/(dim1))+((l-dim2)*y*1/(dim2))))

    
    for k in range(0,int(dim1/2)+1):
        for l in list(range(int(dim2/2)+1, dim2)) :
            somme = somme + u_tf[k, l]* c_exp(-2*math.pi*((k/(dim1))*to1+((l-dim2)/(dim2))*to2))* c_exp(2*math.pi*((k*x*1/(dim1))+((l-dim2)*y*1/(dim2))))
    
    for k in  list(range(int(dim1/2)+1, dim1)) :
        for l in range(0, int(dim2/2)+1):
            somme = somme + u_tf[k, l]* c_exp(-2*math.pi*(((k-dim1)/(dim1))*to1+(l/(dim2))*to2))* c_exp(2*math.pi*(((k-dim1)*x*1/(dim1))+(l*y*1/(dim2))))
 
    
    
    
    
    return somme


def translation (u , to1, to2 ):
    u_tf = np.fft.fft2(u)
    tr= np.zeros( u.shape, dtype =complex)
    dim1, dim2 = u.shape
    
    for x in range(int(dim1)):
        for y in range(int(dim2)):
            tr[x, y] = interpolation(u_tf, to1, to2, x, y  )
    



    
    return tr

# %%
im_t = translation (img, 10, 10.56666 )
plt.imshow(im_t.real)
plt.show()

# %%
def translation_1d (u , to1 ):
    u_tf = np.fft.fft(u)
    tr= np.zeros( u.shape, dtype =complex)
    dim1 = len(u)
    for x in range(int(dim1)):
        tr[x] = interpolation_1d(u_tf, to1, x  )
    return tr

def c_exp( arg):
    return cmath.rect(1, arg)

def interpolation_1d(u_tf, to1,  x):
    somme = 0 
    #dim1, dim2 = u_tf.shape
    dim1 =len(u_tf)
    
    zero=[0]
    for k in range(0,int(dim1/2)+1):
        
        
        somme = somme + u_tf[k]* c_exp(-2*math.pi*((k/(dim1))*to1))* c_exp(2*math.pi*((k*x*1/(dim1))))

    for k in list(range(int(dim1/2)+1, dim1))   :
        somme = somme + u_tf[k]* c_exp(-2*math.pi*(((k-dim1)/(dim1))*to1))* c_exp(2*math.pi*(((k-dim1)*x*1/(dim1))))

    

    
    
    
    return somme

# %%
def prim_t(u, theta):
    for i in range(len(u)):
        tr= translation(u,-i*np.tan(theta),0 )
        u[i, :]= tr[i, :]
    return u 
essai = prim_t(img, math.pi/2)
# Out:
# D:\Programmes\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: ComplexWarning: Casting complex values to real discards the imaginary part
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-d501b3cff433> in <module>()
#       4         u[i, :]= tr[i, :]
#       5     return u
# ----> 6 essai = prim_t(img, math.pi/2)
#       7
#
# <ipython-input-46-d501b3cff433> in prim_t(u, theta)
#       1 def prim_t(u, theta):
#       2     for i in range(len(u)):
# ----> 3         tr= translation(u,i*np.tan(theta),0 )
#       4         u[i, :]= tr[i, :]
#       5     return u
#
# <ipython-input-31-37248bd0b55d> in translation(u, to1, to2)
#      38     for x in range(int(dim1)):
#      39         for y in range(int(dim2)):
# ---> 40             tr[x, y] = interpolation(u_tf, to1, to2, x, y  )
#      41
#      42
#
# ...

# %%
plt.imshow(essai.reel)
plt.show()

print(len(u))
    tr = np.zeros(u.shape)
    for i in range(len(u)):
        tr[i,: ] = translation(u[i, :] ,-i*np.tan(theta),0 )
        u[i, :]= tr[i, :]
    plt.imshow(u.real)
    plt.show()

# %%
def prim_t(u, theta):
    
    tr = np.zeros(u.shape)
    for i in range(len(u)):
        tr[i,: ] = translation_1d(u[i, :] ,-i*np.tan(theta/2) )
    plt.imshow(tr.real)
    plt.show()
    u =tr 
    for i in range(len(u)):
        tr[:,i ] = translation_1d(u[: , i] , i*np.sin(theta))
        u[:,i]= tr[:,i]
    
    plt.imshow(u.real)
    plt.show()
        
    for i in range(len(u)):
        tr[i,: ] = translation_1d(u[i,:] ,-i*np.tan(theta/2) )
        u[i, :]= tr[i, :]
    
    plt.imshow(u.real)
    plt.show()
    
    return u 
    
    
    
essai = prim_t(img, math.pi/5)
# Out:
# D:\Programmes\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: ComplexWarning: Casting complex values to real discards the imaginary part
#   """
# D:\Programmes\Anaconda2\lib\site-packages\ipykernel_launcher.py:10: ComplexWarning: Casting complex values to real discards the imaginary part
#   # Remove the CWD from sys.path while we load stuff.
# D:\Programmes\Anaconda2\lib\site-packages\ipykernel_launcher.py:17: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
img = np.zeros((50, 50))
img[20:25, 20:25]=1

plt.imshow(img)
plt.show()

# %%
plt.imshow(essai.real)
plt.show()

# %%
Metttre en oeuvre l'algorithme suivant: 
iterer p.ex 10 fois 
image=image- \epsilon *Laplacien(image), 
avec p. ex epsilon = . 
Condition de bord = stricte (reduction de l'image à chaque iteration).
                             
I= double(imread(’lena.bmp’))/255;
grad_x=I(1 :end-1, :)-I(2 :end, :);
grad_y=I( :,1 :end-1)-I( :,2 :end); 
(C’est la formule ”fpx`hq´fpxq h ”) 
Pour obtenir la magnitude : 
                             
grad mag=sqrt(grad x( :,1 :end-1).ˆ2+grad y(1 :end-1, :)ˆ2);
(On tronque l’´eg`erement `a cause des eﬀets de bords.)

# %%
def gradient(u):
    grad_x = u[0 :-1, :]- u[1 :, :]
    grad_y= u[:,0:-1]- u[:,1 :]
    magnitude = np.power(np.power(grad_x[:,:-1],2)+np.power(grad_y[:-1,:],2), 1/2)
    return grad_x, grad_y , magnitude

def Laplacien(grad_x, grad_y):
    grad2_x = grad_x[0 :-1, :] -grad_x[1 :, :]
    grad2_y = grad_y[:,0:-1]- grad_y[:,1 :]
    return grad2_x, grad2_y


def algo( u, epsilon, grad_x, grad_y):
    u = u[2:,:]
    for p  in range(10):
        
        u = u - epsilon *Laplacien(grad_x, grad_y)[0]
    plt.imshow(u)
    plt.show()
    
    return u

# %%
femme = f =misc.imread('lena.bmp',flatten=False, mode= 'F')
femme= femme / 255

grad_x, grad_y, magnitude = gradient(f)
grad2_x, grad2_y = Laplacien(grad_x, grad_y)
print(grad_x.shape , f.shape)
print(grad2_x.shape, grad2_y.shape )
# Out:
# (511, 512) (512, 512)
# (510, 512) (512, 510)

# %%
algo(f,1, grad_x, grad_y)
# Out:
# array([[ 162.,  162.,  162., ...,  170.,  155.,  128.],
#        [ 162.,  162.,  162., ...,  170.,  155.,  128.],
#        [ 162.,  162.,  162., ...,  170.,  155.,  128.],
#        ...,
#        [  -7.,   -7.,   70., ...,  174.,  120.,  138.],
#        [   4.,    4.,    5., ...,  124.,   75.,   28.],
#        [  54.,   54.,  105., ...,  104.,  155.,  208.]], dtype=float32)

# %%
plt.imshow(grad_x)
plt.show()
plt.imshow(grad_y)
plt.show()
plt.imshow(magnitude)
plt.show()

# %%
femme = f =misc.imread('lena.bmp',flatten=False, mode= 'RGB')
femme= femme / 255
inv_femme = 1- femme 
plt.imshow(inv_femme)
plt.show()
